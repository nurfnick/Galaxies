# %% [markdown]
# <a href="https://colab.research.google.com/github/nurfnick/Galaxies/blob/main/Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pa
import plotly.express as px

url = 'https://raw.githubusercontent.com/nurfnick/Galaxies/main/nz40.csv'
data = pa.read_csv(url)

# %%
data = data[1:-7] #removing

# %% [markdown]
# You acn

# %%
px.scatter(data, x = "RA (1950)", y = "Dec m_zw", color = "v_h", hover_name= "Name")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7e1aed9b-2d48-4e75-801b-ccfa41f9c839" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7e1aed9b-2d48-4e75-801b-ccfa41f9c839")) {
#                     Plotly.newPlot(
#                         '7e1aed9b-2d48-4e75-801b-ccfa41f9c839',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "v_h=6605<br>RA (1950)=%{x}<br>Dec m_zw=%{y}", "legendgroup": "v_h=6605", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "v_h=6605", "showlegend": true, "type": "scattergl", "x": ["36", "160436"], "xaxis": "x", "y": ["21420014.4", "30140014.4"], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "v_h=7323<br>RA (1950)=%{x}<br>Dec m_zw=%{y}", "legendgroup": "v_h=7323", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "v_h=7323", "showlegend": true, "type": "scattergl", "x": ["36"], "xaxis": "x", "y": ["-2110014.3"], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "v_h=1050<br>RA (1950)=%{x}<br>Dec m_zw=%{y}", "legendgroup": "v_h=1050", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "markers", "name": "v_h=1050", "showlegend": true, "type": "scattergl", "x": ["41.1"], "xaxis": "x", "y": ["15520312"], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "v_h=7301<br>RA (1950)=%{x}<br>Dec m_zw=%{y}", "legendgroup": "v_h=7301", "marker": {"color": "#ab63fa", "symbol": "circle"}, "mode": "markers", "name": "v_h=7301", "showlegend": true, "type": "scattergl", "x": ["100"], "xaxis": "x", "y": ["22560014"], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "v_h=5241<br>RA (1950)=%{x}<br>Dec m_zw=%{y}", "legendgroup": "v_h=5241", "marker": {"color": "#FFA15A", "symbol": "circle"}, "mode": "markers", "name": "v_h=5241", "showlegend": true, "type": "scattergl", "x": ["112"], "xaxis": "x", "y": ["7110014"], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "v_h=2309<br>RA (1950)=%{x}<br>Dec m_zw=%{y}", "legendgroup": "v_h=2309", "marker": {"color": "#19d3f3", "symbol": "circle"}, "mode": "markers", "name": "v_h=2309", "showlegend": true, "type": "scattergl", "x": ["124.9"], "xaxis": "x", "y": ["20281812.7"], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "v_h=4953<br>RA (1950)=%{x}<br>Dec m_zw=%{y}", "legendgroup": "v_h=4953", "marker": {"color": "#FF6692", "symbol": "circle"}, "mode": "markers", "name": "v_h=4953", "showlegend": true, "type": "scattergl", "x": ["148", "231543.9"], "xaxis": "x", "y": ["31120014.3", "6184513.8"], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "v_h=3064<br>RA (1950)=%{x}<br>Dec m_zw=%{y}", "legendgroup": "v_h=3064", "marker": {"color": "#B6E880", "symbol": "circle"}, "mode": "markers", "name": "v_h=3064", "showlegend": true, "type": "scattergl", "x": ["200"], "xaxis": "x", "y": ["4550013.9"], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "v_h=6134<br>RA (1950)=%{x}<br>Dec m_zw=%{y}", "legendgroup": "v_h=6134", "marker": {"color": "#FF97FF", "symbol": "circle"}, "mode": "markers", "name": "v_h=6134", "showlegend": true, "type": "scattergl", "x": ["236"], "xaxis": "x", "y": ["6380014.5"], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "v_h=7730<br>RA (1950)=%{x}<br>Dec m_zw=%{y}", "legendgroup": "v_h=7730", "marker": {"color": "#FECB52", "symbol": "circle"}, "mode": "markers", "name": "v_h=7730", "showlegend": true, "type": "scattergl", "x": ["345.1"], "xaxis": "x", "y": ["19552714"], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "v_h=4534<br>RA (1950)=%{x}<br>Dec m_zw=%{y}", "legendgroup": "v_h=4534", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "v_h=4534", "showlegend": true, "type": "scattergl", "x": ["442", "3848.6"], "xaxis": "x", "y": ["27260013.4", "25133013"], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "v_h=8741<br>RA (1950)=%{x}<br>Dec m_zw=%{y}", "legendgroup": "v_h=8741", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "v_h=8741", "showlegend": true, "type": "scattergl", "x": ["536"], "xaxis": "x", "y": ["26440014.4"], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "v_h=3940 ...

# %%
data["RA (1950)"]
# Out:
# 0            NaN
# 1             36
# 2             36
# 3           41.1
# 4            100
#           ...
# 2391    235852.7
# 2392      235854
# 2393      235906
# 2394      235912
# 2395      235948
# Name: RA (1950), Length: 2396, dtype: object
